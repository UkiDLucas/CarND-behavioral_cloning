# %% [markdown]
# # How to run the simulator
# $ python drive.py model.h5

# %% [raw]
# # Install dependencies
# - $ conda install -c conda-forge opencv
# - $ conda install -c conda-forge Pillow
# - $ conda install flask
# - $ conda install -c conda-forge numpy
# - $ conda install -c conda-forge flask-socketio
# - $ conda install -c conda-forge eventlet
# - $ conda install -c conda-forge keras
# matplotlib

# %%
import argparse
import base64
import json
import numpy as np
import time
import eventlet
import eventlet.wsgi
import tensorflow as tf
import socketio

from PIL import Image
from PIL import ImageOps
from flask import Flask, render_template
from io import BytesIO
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array

# if says Using Theano backend.
# $ edit ~/.keras/keras.json
# change to:
# "backend": "tensorflow",
# Out:
# Using TensorFlow backend.

# %%
# https://github.com/fchollet/keras/issues/3857
tf.python.control_flow_ops = tf

# %%
sio = socketio.Server()
app = Flask(__name__)
model = None
prev_image_array = None

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import numpy as np

t0 = time.time()

@sio.on('telemetry')
def telemetry(sid, data):
    with open("output.txt", "a") as myfile:
        myfile.write("===== new frame: " + "\n")
        
        # The current steering angle of the car
        steering_angle = data["steering_angle"]
        myfile.write("steering = " + steering_angle + "\n")
        
        # The current throttle of the car
        throttle = data["throttle"]
        myfile.write("throttle = " + throttle + "\n")

        # The current speed of the car
        speed = data["speed"]
        myfile.write("speed    = " +  speed + "\n")

        # The current image from the center camera of the car
        #imgString = data["image"]
        #img=mpimg.imread(imgString)
        #plt.imshow(img)

        #image = Image.open(BytesIO(base64.b64decode(imgString)))
        #image_array = np.asarray(image)
        #transformed_image_array = image_array[None, :, :, :]
        # This model currently assumes that the features of the model are just the images. 
        # Feel free to change this.
        #steering_angle = float(model.predict(transformed_image_array, batch_size=1))
        steering_angle = 0.0
        # The driving model currently just outputs a constant throttle. Feel free to edit this.
        throttle = 0.2
        print(steering_angle, throttle)
        send_control(steering_angle, throttle)

# %%
@sio.on('connect')
def connect(sid, environ):
    print("connect ", sid)
    send_control(0, 0)

# %%
def send_control(steering_angle=0.0, throttle=0.2):
    sio.emit("steer", data={
    'steering_angle': steering_angle.__str__(),
    'throttle': throttle.__str__()
    }, skip_sid=True)

# %%
if __name__ == '__main__':
    #parser = argparse.ArgumentParser(description='Remote Driving')
    #parser.add_argument('model', type=str,
    #help='Path to model definition h5. Model should be on the same path.')
    #args = parser.parse_args()

    # model = load_model(args.model)
    #model = load_model("./model.h5")
    
    # wrap Flask application with engineio's middleware
    app = socketio.Middleware(sio, app)

    # deploy as an eventlet WSGI server
    eventlet.wsgi.server(eventlet.listen(('', 4567)), app)
# Out:
# (38105) wsgi starting up on http://0.0.0.0:4567
# (38105) accepted ('127.0.0.1', 52995)
# connect  8217a5bb3faa42a29854dbdea947106f
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:04] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.432717
# (38105) accepted ('127.0.0.1', 52996)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:04] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.039582
# (38105) accepted ('127.0.0.1', 52997)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.027367
# (38105) accepted ('127.0.0.1', 52998)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.022099
# (38105) accepted ('127.0.0.1', 52999)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.022038
# (38105) accepted ('127.0.0.1', 53000)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.026586
# (38105) accepted ('127.0.0.1', 53001)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
# connect  740c486c1b274558b7883b2ad6c5881b
# connect  07b6d4c901fd49908aed313b85e93835
# connect  146aac42883d4726a3786782d6c7773b
# connect  1b07b98d4c764d8cb3b75b6eb8417c74
# connect  9d07ab319f7f42c18201ef79d0a84707
# connect  f311a34917024c2a84a411213713c557
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.031947
# (38105) accepted ('127.0.0.1', 53002)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.028177
# (38105) accepted ('127.0.0.1', 53003)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.027277
# (38105) accepted ('127.0.0.1', 53004)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.033869
# (38105) accepted ('127.0.0.1', 53005)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.035372
# (38105) accepted ('127.0.0.1', 53006)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.034295
# (38105) accepted ('127.0.0.1', 53007)
# connect  dd7de1a44f584054895fdd33bcd501cf
# connect  4207e4d2c9944830b6bebe506e30e0bd
# connect  ba3b15f80eb6423c8c4d20938b7c2687
# connect  8ed16cc494d8478585fb33d9847b3f29
# connect  e67e1327a9bf4d088a9268913383ce62
# connect  d6cfad18044c4314a27e1aaf2fcbef60
# connect  0f44ad244adf4ecfb6d3e8405fef90c7
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.033735
# (38105) accepted ('127.0.0.1', 53008)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:05] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.028713
# (38105) accepted ('127.0.0.1', 53009)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
# ...
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:30] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.056404
# (38105) accepted ('127.0.0.1', 53585)
# connect  9bf4846d5e49406a9527db6240a76c38
# connect  f8718a321d1a4365b65b357597a1fffb
# connect  ba5d670e9bf0453588b573f97c9e5870
# connect  ddf59e914dae498aa54b2bb400e0fa2f
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:30] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.047206
# (38105) accepted ('127.0.0.1', 53586)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:30] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.048211
# (38105) accepted ('127.0.0.1', 53587)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:30] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.050991
# (38105) accepted ('127.0.0.1', 53588)
# Traceback (most recent call last):
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/wsgi.py", line 481, in handle_one_response
#     result = self.application(self.environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/middleware.py", line 47, in __call__
#     return self.engineio_app.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 332, in handle_request
#     return self.eio.handle_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 230, in handle_request
#     transport, b64)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 334, in _handle_connect
#     return s.handle_get_request(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 80, in handle_get_request
#     start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 119, in _upgrade_websocket
#     return ws(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/async_eventlet.py", line 14, in __call__
#     return super(WebSocketWSGI, self).__call__(environ, start_response)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/eventlet/websocket.py", line 127, in __call__
#     self.handler(ws)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 185, in _websocket_handler
#     self.receive(pkt)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/socket.py", line 49, in receive
#     async=self.server.async_handlers)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/engineio/server.py", line 357, in _trigger_event
#     return self.handlers[event](*args)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 489, in _handle_eio_message
#     self._handle_event(sid, pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 428, in _handle_event
#     self._handle_event_internal(self, sid, data, namespace, id)
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 431, in _handle_event_internal
#     r = server._trigger_event(data[0], namespace, sid, *data[1:])
#   File "/Users/ukilucas/anaconda3/envs/tensorflow_cpu/lib/python3.5/site-packages/socketio/server.py", line 460, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "<ipython-input-4-737fffb2c9ff>", line 11, in telemetry
#     myfile.write("===== new frame: " + (time.time()-t0) + "\n")
# TypeError: Can't convert 'float' object to str implicitly
#
# 127.0.0.1 - - [03/Feb/2017 02:53:30] "GET /socket.io/?EIO=4&transport=websocket HTTP/1.1" 500 3230 0.046034
# (38105) accepted ('127.0.0.1', 53589)
